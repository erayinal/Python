# %% [markdown]
# # **Overfitting, Underfitting, Bias-Variance Dengesi**
# <img src="attachment:5efbef29-2e4b-41ef-a10b-c04ff230294c.png" width="50%">
#
# # Overfitting:
# * Model, eğitim verisini neredeyse ezberlemişse ama yeni veriler başarısız oluyorsa -> Overfitting
# *
