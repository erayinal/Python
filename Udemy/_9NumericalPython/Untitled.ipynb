# %%
import numpy as np

# %%
a = np.random.randint(10, size=(5,5))
a
# Out:
# array([[9, 3, 3, 7, 6],
#        [8, 1, 8, 6, 1],
#        [5, 9, 6, 6, 5],
#        [8, 0, 1, 7, 1],
#        [6, 9, 6, 7, 4]])

# %%
a[0][0]
# Out:
# 9

# %%
a[:,0]
# Out:
# array([7, 6, 6, 7, 7])

# %%
a[3,:]
# Out:
# array([8, 0, 1, 7, 1])

# %%
a[0:2 , 0:3]
# Out:
# array([[9, 3, 3],
#        [8, 1, 8]])
